# %% [markdown]
# ### This demo shows how to detect faces from video and displays result in realtime
#
# You need OpenCV installed to run this example. To install it, run ___pip install opencv-python___

# %%
# %pylab inline 
import face_recognition
import cv2
import matplotlib.patches as patches
from IPython.display import clear_output
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Load some sample pictures and learn how to recognize them.
en_image = face_recognition.load_image_file("../avatar_evelien.jpg")
en_face_encoding = face_recognition.face_encodings(en_image)[0]

ei_image = face_recognition.load_image_file("../avatar_evi.jpg")
ei_face_encoding = face_recognition.face_encodings(ei_image)[0]

ji_image = face_recognition.load_image_file("../avatar_jamie.jpg")
ji_face_encoding = face_recognition.face_encodings(ji_image)[0]

ml_image = face_recognition.load_image_file("../avatar_merel.jpg")
ml_face_encoding = face_recognition.face_encodings(ml_image)[0]

ns_image = face_recognition.load_image_file("../avatar_niels.jpg")
ns_face_encoding = face_recognition.face_encodings(ns_image)[0]

ne_image = face_recognition.load_image_file("../avatar_nikkie.jpg")
ne_face_encoding = face_recognition.face_encodings(ne_image)[0]

rl_image = face_recognition.load_image_file("../avatar_rickpaul.jpg")
rl_face_encoding = face_recognition.face_encodings(rl_image)[0]

rt_image = face_recognition.load_image_file("../avatar_robert.jpg")
rt_face_encoding = face_recognition.face_encodings(rt_image)[0]

sh_image = face_recognition.load_image_file("../avatar_sarah.jpg")
sh_face_encoding = face_recognition.face_encodings(sh_image)[0]

sn_image = face_recognition.load_image_file("../avatar_sinan.jpg")
sn_face_encoding = face_recognition.face_encodings(sn_image)[0]

known_faces = [
    en_face_encoding,
    ei_face_encoding,
    ji_face_encoding,
    ml_face_encoding,
    ns_face_encoding,
    ne_face_encoding,
    rl_face_encoding,
    rt_face_encoding,
    sh_face_encoding,
    sn_face_encoding,
]

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
frame_number = 0

# %%
evelien = 0
evi = 0
jamie = 0
merel = 0
niels = 0
nikkie = 0
rickpaul = 0
robert = 0
sarah = 0
sinan = 0

# %%
# Create an output movie file (make sure resolution/frame rate matches input video!)
fourcc = cv2.VideoWriter_fourcc(*'XVID')
output_movie = cv2.VideoWriter('output_2019.avi', fourcc, 25, (640, 360))

# %%
# Loading video for face detection
# afl1 : bb_AT_2091347.m4v
# afl2 : bb_AT_2091348.m4v
# afl3 : bb_AT_2091349.m4v
# afl4 : bb_AT_2091350.m4v
video_capture = cv2.VideoCapture("../bb_AT_2111641.m4v")
length = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
print(length)
# Out:
# 91813

# %%
frame_count = 0
a = False

while video_capture.isOpened():    
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Bail out when the video file ends
    if not ret:
        video_capture.release()
        break
        
    # We will search face in every 15 frames to speed up process.
    frame_count += 1
    if frame_count % 500 == 0:
        print('{}/{}'.format(frame_count,length))
    if frame_count % 15 == 0:    
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)      

        # Find all the faces and face encodings in the current frame of video
        rgb_frame = frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_frame)
        face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            match = face_recognition.compare_faces(known_faces, face_encoding, tolerance=0.50)

            # If you had more than 2 faces, you could make this logic a lot prettier
            # but I kept it simple for the demo
            name = None
            if match[0]:
                evelien += 1    
                name='evelien'
            elif match[1]:
                evi += 1
                name='evi'
            elif match[2]:                
                jamie += 1
                name='jamie'
            elif match[3]:                
                merel += 1
                name= 'merel'
            elif match[4]:                
                niels += 1
                name= 'niels'
            elif match[5]:                
                nikkie += 1
                name = 'nikkie'
            elif match[6]:                
                rickpaul += 1
                name = 'rickpaul'
            elif match[7]:                
                robert += 1
                name = 'robert'
            elif match[8]:            
                sarah += 1
                name = 'sarah'
            elif match[9]:                
                sinan += 1 
                name = 'sinan'
            
            face_names.append(name)
        
        for (top, right, bottom, left), name in zip(face_locations, face_names):
            if not name:
                continue
                
            cv2.rectangle(frame, (left, top), (right, bottom), (0,0, 255),2)
            
            cv2.rectangle(frame, (left, bottom -25), (right, bottom), (0,0,255), cv2.FILLED)
            font = cv2.FONT_HERSHEY_DUPLEX
            cv2.putText(frame, name, (left +